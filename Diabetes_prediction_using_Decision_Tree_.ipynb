# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanush-Karthik16/Diabetes_prediction_using_Decision_Tree/blob/main/Diabetes_prediction_using_Decision_Tree_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # **EDA**

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.info
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.shape
# Out:
# (768, 9)

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df = pd.DataFrame(data)
duplicates = df.duplicated()
print(duplicates)
print(df[df.duplicated()])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool
# Empty DataFrame
# Columns: [Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome]
# Index: []

# %% [markdown]
# # **MATPLOTLIB**

# %%
import matplotlib.pyplot as plt

x=data['BMI']
y=data['Age']

plt.scatter(x,y)
plt.xlabel('BMI')
plt.ylabel('AGE')
plt.title('Scatter Plot')
plt.show()

# %%
x = data['BloodPressure']
plt.plot(x)
plt.xlabel('BloodPressure')
plt.title('Line Plot')
plt.show()

# %%
x = data['BloodPressure']
plt.hist(x)
plt.xlabel('BloodPressure')
plt.title('Histogram')
plt.show()

# %%
x=data['Age']
y=data['BloodPressure']

plt.bar(x,y)
plt.xlabel('AGE')
plt.ylabel('BloodPressure')
plt.title('Bar Plot')
plt.show()

# %%
x = data['BloodPressure']
plt.pie(x)
plt.xlabel('BloodPressure')
plt.title('pie')
plt.show()

# %% [markdown]
# # **SEABORN**

# %%
sns.lineplot(x=data['Age'],y=data['BloodPressure'],data=data)
# Out:
# <Axes: xlabel='Age', ylabel='BloodPressure'>

# %%
sns.scatterplot(x='Age',y='BMI',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='BMI'>

# %%
sns.barplot(x='Age',y='Insulin',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='Insulin'>

# %%
sns.distplot(x=data['Insulin'])
# Out:
# /tmp/ipython-input-16-299710077.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['Insulin'])
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x='Age',y='BloodPressure',data=data)
# Out:
# <Axes: xlabel='Age', ylabel='BloodPressure'>

# %%
sns.pairplot(data,hue='Insulin')

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
x=data.iloc[:,:8]
y=data['Outcome']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
ypred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,ypred)
# Out:
# 0.6883116883116883

# %%
from sklearn import tree
tree.plot_tree(model)
# Out:
# [Text(0.5051429020100503, 0.96875, 'x[1] <= 123.5\ngini = 0.449\nsamples = 614\nvalue = [405, 209]'),
#  Text(0.19558731155778894, 0.90625, 'x[7] <= 28.5\ngini = 0.3\nsamples = 370\nvalue = [302, 68]'),
#  Text(0.35036510678391963, 0.9375, 'True  '),
#  Text(0.10741206030150753, 0.84375, 'x[5] <= 45.4\ngini = 0.158\nsamples = 208\nvalue = [190, 18]'),
#  Text(0.07160804020100503, 0.78125, 'x[5] <= 30.95\ngini = 0.136\nsamples = 204\nvalue = [189, 15]'),
#  Text(0.03015075376884422, 0.71875, 'x[0] <= 7.5\ngini = 0.034\nsamples = 117\nvalue = [115, 2]'),
#  Text(0.020100502512562814, 0.65625, 'x[6] <= 0.672\ngini = 0.017\nsamples = 116\nvalue = [115, 1]'),
#  Text(0.010050251256281407, 0.59375, 'gini = 0.0\nsamples = 102\nvalue = [102, 0]'),
#  Text(0.03015075376884422, 0.59375, 'x[6] <= 0.686\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.020100502512562814, 0.53125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...

# %%
from sklearn.tree import export_graphviz
import graphviz
graphviz.Source(export_graphviz(model,feature_names=x.columns,filled=True))
